# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %%
# --- EXAMPLES ---

# Integers
subscriber_count = 10_000_000
age = 25

# Floats
monthly_bill = 89_500.50
accuracy = 0.95

# Strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

# Booleans
is_active = True
payment_on_time = False

# Lists
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

# Check types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")



# This script defines various data types in Python( Integers, Floats, Strings, Booleans and Lists ) and prints their technical classification.
# Whole numbers (Integers) - underscores are used for readability.
# Decimal numbers (Floats) for precise values like currency.
# Text data (Strings) enclosed in quotes.
# Logic switches (Booleans) - must be True or False.
# Collections (Lists) used to store multiple related items in one variable.
# Out:
# subscriber_count: 10000000 (type: int)
# monthly_bill:     89500.5 (type: float)
# customer_name:    Abdullayev Jasur (type: str)
# is_active:        True (type: bool)
# monthly_bills:    [85000, 92000, 78000, 95000, 88000] (type: list)

# %%
# --- List operations ---

# Access by index (0-based)
# [0] is the first item, [-1] is the last item
print(f"First bill: {monthly_bills[0]}")
print(f"Last bill:  {monthly_bills[-1]}")


# Slicing
# Extracts a portion of the list from the start up to (but not including) index 3
print(f"First 3 bills: {monthly_bills[:3]}")

# Length
# Returns the total count of elements in the list
print(f"Number of bills: {len(monthly_bills)}")

# Append
# Dynamically adds a new value to the end of the list
monthly_bills.append(91000)
print(f"After append: {monthly_bills}")
# Out:
# First bill: 85000
# Last bill:  88000
# First 3 bills: [85000, 92000, 78000]
# Number of bills: 5
# After append: [85000, 92000, 78000, 95000, 88000, 91000]

# %%
# --- TODO: Variables exercise ---
# Create variables for a telecom customer profile:

# TODO: Create an integer variable for the customer's age
customer_age = 18

# TODO: Create a float variable for their monthly data usage in GB
data_usage_gb = 65

# TODO: Create a string variable for their city
city = "Tashkent"

# TODO: Create a boolean for whether they have a contract (vs prepaid)
has_contract = True

# TODO: Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = [60000, 75000, 72000, 65000, 80000, 85000]

# TODO: Print all variables with their types (follow the example pattern above)
print(f"Customer Age: {customer_age} | Type: {type(customer_age)}")
print(f"Data Usage (GB): {data_usage_gb} | Type: {type(data_usage_gb)}")
print(f"City: {city} | Type: {type(city)}")
print(f"Has Contract: {has_contract} | Type: {type(has_contract)}")
print(f"Monthly Bills (Soum): {monthly_bills} | Type: {type(monthly_bills)}")

# This script initializes a customer's profile data using various  Python data types and verifies the data structure for system processing.
# Integer: Representing the customer's age in years
# Float: Monthly data usage measured in Gigabytes (precision is key here)
# String: The customer's current city of residence
# Boolean: Logical flag (True if on a contract, False if prepaid)
# List: Historical billing data for the last 6 months (values in Uzbek Soum)
# Out:
# Customer Age: 18 | Type: <class 'int'>
# Data Usage (GB): 65 | Type: <class 'int'>
# City: Tashkent | Type: <class 'str'>
# Has Contract: True | Type: <class 'bool'>
# Monthly Bills (Soum): [85000, 92000, 78000, 95000, 88000, 91000] | Type: <class 'list'>

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"
}

# Access values by key
print(f"Customer: {customer['name']}")
print(f"Region:   {customer['region']}")
print(f"Spend:    {customer['monthly_spend']} soum")

# Add a new key
customer["tenure_months"] = 24
print(f"\nFull record: {customer}")

# This script demonstrates how to store structured data using key-value pairs, access specific fields, and update records.
# Out:
# Customer: Karimov Sherzod
# Region:   Tashkent
# Spend:    125000 soum
#
# Full record: {'id': 'UZT-001234', 'name': 'Karimov Sherzod', 'region': 'Tashkent', 'monthly_spend': 125000, 'is_active': True, 'plan': 'Premium', 'tenure_months': 24}

# %%
# --- TODO: Dictionary exercise ---
# Create a dictionary representing a product from an e-commerce store
# Include at least 5 keys: name, category, price, quantity_sold, rating

# TODO: Create the product dictionary
product = {
    "name": "Samsung Galaxy S24 Ultra",
    "category": "Electronics",
    "price": 15000000,
    "quantity_sold": 142,
    "rating": 4.8
}

# TODO: Print the product name and price
print(f"Product Name: {product['name']}")
print(f"Price: {product['price']} UZS")

# TODO: Add a new key "discount" with a value between 0 and 1
product["discount"] = 0.15

# TODO: Print all keys using product.keys()
print("\nProduct keys:")
print(product.keys())

# This script demonstrates how to define a product as a dictionary, access its attributes, and dynamically update its properties.
# Out:
# Product Name: Samsung Galaxy S24 Ultra
# Price: 15000000 UZS
#
# Product keys:
# dict_keys(['name', 'category', 'price', 'quantity_sold', 'rating', 'discount'])

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")

# This script defines a reusable function for statistical calculations and applies it to a set of monthly billing data.
# Out:
# Average monthly bill: 88,167 soum

# %%
def describe_bills(bills):
  """
    Analyzes a list of numbers and returns a summary.
    Returns:
        - avg: The arithmetic mean
        - minimum: The lowest value in the set
        - maximum: The highest value in the set
    """
  avg = sum(bills) / len(bills)
  minimum = min(bills)
  maximum = max(bills)
  return avg, minimum, maximum

# The three returned values are 'unpacked' into three separate variables
avg, low, high = describe_bills(bills)
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")

# This script calculates and extracts multiple statistical metrics (Average, Min, Max) from a list in a single function call.
# Out:
# Average: 88,167 | Min: 78,000 | Max: 95,000

# %%
# --- TODO: Write your own functions ---

# TODO 1: Write a function called `classify_customer` that takes monthly_spend as input
#         and returns:
#         - "premium" if spend > 150000
#         - "standard" if spend is between 50000 and 150000 (inclusive)
#         - "basic" if spend < 50000

def classify_customer(monthly_spend):
  """
    Determines the customer segment based on spending thresholds.

    Rules:
    - > 150,000: Premium
    - 50,000 to 150,000: Standard
    - < 50,000: Basic
    """
  # TODO: implement this function
  if monthly_spend > 150000:
    return "premium"
  elif 50000 <= monthly_spend <= 150000:
    return "standard"
  else:
    return "basic"

# Test your function:
print(classify_customer(200000))  # should print "premium"
print(classify_customer(75000))   # should print "standard"
print(classify_customer(30000))   # should print "basic"

# Logic to categorize customers into service tiers based on their monthly expenditure.
# Out:
# premium
# standard
# basic

# %%
# TODO 2: Write a function called `calculate_churn_rate` that takes two arguments:
#         - total_customers (int)
#         - churned_customers (int)
#         Returns the churn rate as a percentage (float).

def calculate_churn_rate(total_customers, churned_customers):
  """
    Calculates the percentage of customers lost over a specific period.

    Args:
        total_customers (int): The total count of customers at the start.
        churned_customers (int): The number of customers who left.

    Returns:
        float: The churn rate as a percentage (e.g., 3.5 for 3.5%).
    """
  # TODO: implement this function
  if total_customers == 0:
      return 0.0
  return (churned_customers / total_customers) * 100.0

# Test:
print(calculate_churn_rate(10000, 350))  # should print 3.5

# This script calculates the churn rate, a critical KPI for subscription-based businesses like telecom providers.
# Out:
# 3.5000000000000004

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# --- EXAMPLE: basic for loop ---

# Initialize a list of geographical regions
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]

# Start the iteration process
for region in regions:
    print(f"Processing data for: {region}")

    # Demonstrates the use of a 'for' loop to iterate through a list of geographic locations and execute a standardized task for each
# Out:
# Processing data for: Tashkent
# Processing data for: Samarkand
# Processing data for: Bukhara
# Processing data for: Fergana
# Processing data for: Namangan

# %%
# --- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

# Historical billing data
monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

#Iterating with an index and a value
for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")

    #Uses the enumerate function to iterate through a list while tracking the current index for formatted reporting.
# Out:
# Month 1: 85,000 soum
# Month 2: 92,000 soum
# Month 3: 78,000 soum
# Month 4: 95,000 soum
# Month 5: 88,000 soum
# Month 6: 91,000 soum

# %%
# --- EXAMPLE: loop with conditional ---

#  Dataset: A list containing dictionaries for each customer
customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")

# Iterate through the list
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")

         # Iterates through a dataset of customer records to identify and display only those meeting high-value spending criteria.
# Out:
# High-value customers (spend > 100,000):
#   Alisher: 200,000 soum
#   Bobur: 120,000 soum
#   Rustam: 180,000 soum

# %%
# --- TODO: Loop exercises ---

# TODO 1: Using the `customers` list above, loop through and classify each customer
#         using your classify_customer function from Section 3.
#         Print: "Name: <name>, Tier: <tier>"

# Your code here:
for c in customers:
    # Avvalgi bo'limda yozgan funksiyamizni chaqiramiz
    tier = classify_customer(c["spend"])
    print(f"Name: {c['name']}, Tier: {tier}")

# This script combines iteration and functional logic to assign service tiers to each customer in the database.
# Out:
# Name: Alisher, Tier: premium
# Name: Dilnoza, Tier: basic
# Name: Bobur, Tier: standard
# Name: Malika, Tier: basic
# Name: Rustam, Tier: premium

# %%
# TODO 2: Given the list of scores below, use enumerate to print each score
#         with its rank (starting from 1), and mark scores above 90 with " -- HIGH"
#
# Expected output:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   ...

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Your code here:
for index, score in enumerate(scores):
    rank = index + 1  # Indeks 0 dan boshlangani uchun rank hosil qilishga 1 qo'shamiz

    if score > 90:
        print(f"  Rank {rank}: {score} -- HIGH")
    else:
        print(f"  Rank {rank}: {score}")

# Iterates through a score list to display rankings and automatically highlight high-performing results (>90).
# Out:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   Rank 4: 61
#   Rank 5: 93 -- HIGH
#   Rank 6: 77
#   Rank 7: 85
#   Rank 8: 91 -- HIGH
#   Rank 9: 68
#   Rank 10: 99 -- HIGH

# %%
# TODO 3: Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

# Your code here:
total_sum = 0
count = 0

for score in scores:
    total_sum += score  # Har bir ballni qo'shib boramiz (summa)
    count += 1          # Elementlar sonini sanaymiz (uzunlik)

# O'rtacha qiymatni hisoblaymiz (agar ro'yxat bo'sh bo'lmasa)
average = total_sum / count if count > 0 else 0

print(f"Total: {total_sum}, Average: {average}")

# Computes the sum and average of a numeric list using a for loop, demonstrating manual data aggregation logic.
# Out:
# Total: 829, Average: 82.9

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

# Your code here:
# Initialize counters for each customer tier
premium_count = 0
standard_count = 0
basic_count = 0

# 1. Loop through each customer in the dataset
for customer in customers_data:
  spend = customer["monthly_spend"]

  # 2. Classify into tiers using inline logic and 3. Increment the respective counter
  if spend > 150000:
      premium_count += 1
  elif 50000 <= spend <= 150000:
      standard_count += 1
  else:
      basic_count += 1

# 4. Print the final summary report
print(f"Premium: {premium_count}, Standard: {standard_count}, Basic: {basic_count}")

# Aggregates a dataset of customer records into categorized tiers and calculates the frequency distribution for business reporting.
# Out:
# Premium: 3, Standard: 3, Basic: 2

# %% [markdown]
# Assignment 2

# %%
# Creating variables of different types
age = 22
gpa = 3.85
name = "Aziz"
is_student = True
scores = [85, 92, 78, 95, 88]

# %%
# Printing variables and their types
print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 22 <class 'int'>
# 3.85 <class 'float'>
# Aziz <class 'str'>
# True <class 'bool'>
# [85, 92, 78, 95, 88] <class 'list'>

# %%
# Function to calculate the average of a list
def calculate_average(numbers) :
  total = sum(numbers)
  count = len(numbers)
  return total /  count

  # Testing the function
  test1 = [80, 90, 70, 85, 95]
  test2 = [55, 62, 48, 71]

  print("Average 1:", calculate_average(test1))
  print("Average 2:", calculate_average(test2))

# %%
# Iterating through a list with indices
cities = ["Tashkent", "Samarkand", "Bukhara", "Namanagan", "Fergana"]
for index, city in enumerate(cities):
  print(f"Index {index}: {city}")
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namanagan
# Index 4: Fergana

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)
avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")
if avg >= 60:
  print("Result: Pass")
else:
  print("Result: Fail")
# Out:
# Scores: [31, 54, 23, 57, 25, 50, 67, 83, 34, 0]
# Class average: 42.4
# Result: Fail
